# %% [markdown]
# # ClutchAI MVP
#
# __GOAL__
#
# Create an Agentic AI assistant for Yahoo Fantasy League.
#
# __STEPS__
# 1. Add YahooFantasy API as a Tool
# 2. Create a VectorDB from Josh Llyod Youtube Transcripts
# 3. Run a ReACT Agent
# 4. Test out key usecases:
#     - Give me a weekly summary from last week
#     - Who is more likely to win in week A vs week B
#     - Who is hot on the waiver wire?
#     - Is player A for player B a good trade?

# %% [markdown]
# #### 0. Environment Setup

# %%
import os
from dotenv import load_dotenv
from pathlib import Path
import json

# Load .env file from the project root (parent directory of notebook/)
# Resolve the path to get the absolute path to the .env file
env_file_location = Path('..').resolve()
load_dotenv(dotenv_path=env_file_location / ".env")
print(f"Loading .env from: {env_file_location / '.env'}\n")

# Set env variables
YAHOO_CONSUMER_KEY = os.environ.get('YAHOO_CLIENT_ID', "<INSERT_>")
YAHOO_CONSUMER_SECRET = os.environ.get('YAHOO_CLIENT_SECRET', "<INSERT>")
YAHOO_LEAGUE_ID = 58930
GAME_CODE = "nba"
GAME_ID=466
# Out:
# Loading .env from: /Users/matt/Code/ClutchAI/.env

# %%
# Show which env variables were loaded
env_vars_to_check = ['YAHOO_CLIENT_ID', 'YAHOO_CLIENT_SECRET', 'OPENAI_API_KEY', 'LANGSMITH_API_KEY']
print("Environment variables loaded:")
for var in env_vars_to_check:
    value = os.environ.get(var)
    if value:
        print(f"  ✓ {var}: {value[:10]} + ...")
    else:
        print(f"  ✗ {var}: NOT SET")
# Out:
# Environment variables loaded:
#   ✓ YAHOO_CLIENT_ID: dj0yJmk9Ml + ...
#   ✓ YAHOO_CLIENT_SECRET: 967c74034e + ...
#   ✓ OPENAI_API_KEY: sk-proj-4A + ...
#   ✓ LANGSMITH_API_KEY: lsv2_pt_7c + ...

# %% [markdown]
# #### 1. Connect to YahooFantasy League Data

# %%
from yfpy.query import YahooFantasySportsQuery

# %%
query = YahooFantasySportsQuery(
    league_id=YAHOO_LEAGUE_ID,
    game_code="nba",
    game_id= GAME_ID,
    env_var_fallback = True,
    env_file_location = env_file_location,
    save_token_data_to_env_file = True,
)

# %%
#Data to pull from Yahoo Fantasy
league_meta = query.get_league_metadata()
league_meta_dict = json.loads(league_meta.to_json())
print(len(league_meta))
league_meta_dict
# Out:
# 31
# {'allow_add_to_dl_extra_pos': 1,
#  'current_week': 3,
#  'draft_status': 'postdraft',
#  'edit_key': '2025-11-06',
#  'end_date': '2026-04-05',
#  'end_week': 23,
#  'felo_tier': 'gold',
#  'game_code': 'nba',
#  'iris_group_chat_id': None,
#  'is_cash_league': 0,
#  'is_highscore': False,
#  'is_plus_league': 0,
#  'is_pro_league': 0,
#  'league_id': '58930',
#  'league_key': '466.l.58930',
#  'league_type': 'private',
#  'league_update_timestamp': 1762418787,
#  'logo_url': 'https://yahoofantasysports-res.cloudinary.com/image/upload/t_s192sq/fantasy-logos/56479288575_ec9899.jpg',
#  'matchup_week': 3,
#  'name': 'TK Fiji Fantasy 2024/25',
#  'num_teams': 12,
#  'renew': '454_14696',
#  'renewed': None,
#  'roster_type': 'date',
#  'scoring_type': 'headone',
#  'season': 2025,
#  'start_date': '2025-10-21',
#  'start_week': 1,
#  'url': 'https://basketball.fantasysports.yahoo.com/nba/58930',
#  'weekly_deadline': 'intraday'}

# %% [markdown]
# #### 2. Connecting LangChain Agent to Yahoo API

# %%
from langchain_core.tools import tool
from langchain.agents import create_agent
from langchain_openai import ChatOpenAI

# %%
#Creat YahooFantasy Agent
class YahooFantasyAgent:
    def __init__(self):
        self.YAHOO_CONSUMER_KEY = os.environ.get('YAHOO_CLIENT_ID', "<INSERT_>")
        self.YAHOO_CONSUMER_SECRET = os.environ.get('YAHOO_CLIENT_SECRET', "<INSERT>")
        self.YAHOO_LEAGUE_ID = 58930
        self.GAME_CODE = "nba"
        self.GAME_ID=466

        self.query = YahooFantasySportsQuery(
            league_id=YAHOO_LEAGUE_ID,
            game_code="nba",
            game_id= GAME_ID,
            yahoo_consumer_key = YAHOO_CONSUMER_KEY,
            yahoo_consumer_secret = YAHOO_CONSUMER_SECRET,
            env_var_fallback = True,
            env_file_location = env_file_location,
            save_token_data_to_env_file = True,
        )

    def get_league_metadata(self) -> str:
        """Fetch Yahoo Fantasy league metadata."""
        try:
            data = self.query.get_league_metadata()
            return f'The Yahoo Fantasy league metadata in json format is: {data}'
        except Exception as e:
            return f"Failed to Yahoo Fantasy league metadata: {e}"
        
@tool("YahooLeagueMetDataTool", description="Get Yahoo League Metadata in json format from YPFS.")
def league_metadata_tool() -> str:
    """Get Yahoo League Metadata."""
    return YahooFantasyAgent().get_league_metadata()

# %%
#Create Clutch AI Agent
llm = ChatOpenAI(model_name="gpt-4")
tools = [league_metadata_tool]

ClutchAI_Agent = create_agent(
    model = llm,
    tools = tools,
    system_prompt="You are a helpful assistant for a Yahoo Fantasy Sports league manager.",
)

# %%
#Test Agent
inputs = {"messages": [{"role": "user", "content": "What is the Yahoo Fantasy League Name?"}]}
ClutchAI_Agent.invoke(inputs)
# Out:
# {'messages': [HumanMessage(content='What is the Yahoo Fantasy League Name?', additional_kwargs={}, response_metadata={}, id='be0bc34b-d652-4db6-ad7a-30a203670c98'),
#   AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 11, 'prompt_tokens': 68, 'total_tokens': 79, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4-0613', 'system_fingerprint': None, 'id': 'chatcmpl-CYyQQXznTyQmZiwvN0GCSHTlwvAEB', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--370c7b62-dd66-48ee-b292-c63fb876e9d7-0', tool_calls=[{'name': 'YahooLeagueMetDataTool', 'args': {}, 'id': 'call_QG4XSHuSd0ATgzO6M4OZw55R', 'type': 'tool_call'}], usage_metadata={'input_tokens': 68, 'output_tokens': 11, 'total_tokens': 79, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#   ToolMessage(content='The Yahoo Fantasy league metadata in json format is: League({\n  "allow_add_to_dl_extra_pos": 1,\n  "current_week": 3,\n  "draft_status": "postdraft",\n  "edit_key": "2025-11-06",\n  "end_date": "2026-04-05",\n  "end_week": 23,\n  "felo_tier": "gold",\n  "game_code": "nba",\n  "iris_group_chat_id": null,\n  "is_cash_league": 0,\n  "is_highscore": false,\n  "is_plus_league": 0,\n  "is_pro_league": 0,\n  "league_id": "58930",\n  "league_key": "466.l.58930",\n  "league_type": "private",\n  "league_update_timestamp": 1762418787,\n  "logo_url": "https://yahoofantasysports-res.cloudinary.com/image/upload/t_s192sq/fantasy-logos/56479288575_ec9899.jpg",\n  "matchup_week": 3,\n  "name": "TK Fiji Fantasy 2024/25",\n  "num_teams": 12,\n  "renew": "454_14696",\n  "renewed": null,\n  "roster_type": "date",\n  "scoring_type": "headone",\n  "season": 2025,\n  "start_date": "2025-10-21",\n  "start_week": 1,\n  "url": "https://basketball.fantasysports.yahoo.com/nba/58930",\n  "weekly_deadline": "intraday"\n})', name='YahooLeagueMetDataTool', id='c3a22069-fe4a-47de-b884-bae3a6778320', tool_call_id='call_QG4XSHuSd0ATgzO6M4OZw55R'),
#   AIMessage(content='The Yahoo Fantasy League Name is "TK Fiji Fantasy 2024/25".', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 17, 'prompt_tokens': 441, 'total_tokens': 458, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4-0613', 'system_fingerprint': None, 'id': 'chatcmpl-CYyQSFueC7amjHSEDWkQHKdDlqkrL', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--1a00ea39-b671-4a41-950c-93b3afb3d164-0', usage_metadata={'input_tokens': 441, 'output_tokens': 17, 'total_tokens': 458, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}

# %%
#Stream Agent Response for Debug
for event in ClutchAI_Agent.stream(inputs):
    print(event)
# Out:
# {'model': {'messages': [AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 151, 'prompt_tokens': 151, 'total_tokens': 302, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 128, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CYpF2SldRbg7sMyKpV3AQWihSE8Uo', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--6dce8e7f-3aad-46c1-9c44-95d63b3f2efb-0', tool_calls=[{'name': 'YahooLeagueMetDataTool', 'args': {}, 'id': 'call_HfBWvVMEQmUbQwmIohaNWAGz', 'type': 'tool_call'}], usage_metadata={'input_tokens': 151, 'output_tokens': 151, 'total_tokens': 302, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 128}})]}}
# {'tools': {'messages': [ToolMessage(content='The Yahoo Fantasy league metadata in json format is: League({\n  "allow_add_to_dl_extra_pos": 1,\n  "current_week": 3,\n  "draft_status": "postdraft",\n  "edit_key": "2025-11-06",\n  "end_date": "2026-04-05",\n  "end_week": 23,\n  "felo_tier": "gold",\n  "game_code": "nba",\n  "iris_group_chat_id": null,\n  "is_cash_league": 0,\n  "is_highscore": false,\n  "is_plus_league": 0,\n  "is_pro_league": 0,\n  "league_id": "58930",\n  "league_key": "466.l.58930",\n  "league_type": "private",\n  "league_update_timestamp": 1762332401,\n  "logo_url": "https://yahoofantasysports-res.cloudinary.com/image/upload/t_s192sq/fantasy-logos/56479288575_ec9899.jpg",\n  "matchup_week": 3,\n  "name": "TK Fiji Fantasy 2024/25",\n  "num_teams": 12,\n  "renew": "454_14696",\n  "renewed": null,\n  "roster_type": "date",\n  "scoring_type": "headone",\n  "season": 2025,\n  "start_date": "2025-10-21",\n  "start_week": 1,\n  "url": "https://basketball.fantasysports.yahoo.com/nba/58930",\n  "weekly_deadline": "intraday"\n})', name='YahooLeagueMetDataTool', id='7b73fc51-59f0-4601-920a-a34f82fa1b7c', tool_call_id='call_HfBWvVMEQmUbQwmIohaNWAGz')]}}
# {'model': {'messages': [AIMessage(content='The Yahoo Fantasy League Name is: TK Fiji Fantasy 2024/25. \n\nIf you’d like, I can share additional details (league ID, type, start/end dates, etc.).', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 304, 'prompt_tokens': 531, 'total_tokens': 835, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 256, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CYpF6EeP0e1mQ7ZbptlkxYNFauRxX', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--c410cce6-6810-42fe-ab1e-7540866f1dd4-0', usage_metadata={'input_tokens': 531, 'output_tokens': 304, 'total_tokens': 835, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 256}})]}}

# %% [markdown]
# #### 2. Adding Youtube Transcripts to VectorDB

# %%
from langchain_community.document_loaders import YoutubeLoader
from langchain_community.document_loaders.youtube import TranscriptFormat
from youtube_transcript_api import YouTubeTranscriptApi

# %%
loader = YoutubeLoader.from_youtube_url(
    "https://www.youtube.com/watch?v=TB2QwCRMams&t=2s", 
    add_video_info=False,
    transcript_format=TranscriptFormat.CHUNKS,
    chunk_size_seconds=30
)
loader.load()
# Out:
# [Document(metadata={'source': 'https://www.youtube.com/watch?v=TB2QwCRMams&t=0s', 'start_seconds': 0, 'start_timestamp': '00:00:00'}, page_content="There are a lot of players who are either hurt, injury-prone, susceptible to tanking. So, what do you do in a fantasy draft? When do you take them? Michael Bolton, he's going to give you some answers. >> Thanks, Josh. It's Michael Bolton here, and it's time for another episode of the Locked On Fantasy Basketball Podcast. Let's get to it. >> Let's get to it. Indeed. You are Locked on Fantasy, your daily"),
#  Document(metadata={'source': 'https://www.youtube.com/watch?v=TB2QwCRMams&t=30s', 'start_seconds': 30, 'start_timestamp': '00:00:30'}, page_content="NBA fantasy podcast, part of the Locked On podcast network, your team every day. Hello and welcome to the Locked On Fantasy Basketball podcast brought to you by Basketball Monster. My name is Josh Lloyd and there is no longer a hole in my bucket. I'm also the lead fantasy analyst at basketball.com and today's episode is brought to you by Fanil. Right now, new customers can bet just $5 and if your bet wins, you'll get $300 in"),
#  Document(metadata={'source': 'https://www.youtube.com/watch?v=TB2QwCRMams&t=60s', 'start_seconds': 60, 'start_timestamp': '00:01:00'}, page_content="bonus bets to use across the app. Head to fangel.com to get started. Thank you also for making Locked on Fantasy Basketball your first listen every day. We are free. We are available on all platforms. So, what are we talking about? Injured players. There are different categorizations here. Like I've said, there are players who literally are currently injured. There are players who you think are going to get injured. There are players that we worry about when they're going to be available on tanking teams and how often they're going to play. So, I have got 30 plus names I'm going to talk about here."),
#  Document(metadata={'source': 'https://www.youtube.com/watch?v=TB2QwCRMams&t=90s', 'start_seconds': 90, 'start_timestamp': '00:01:30'}, page_content='There\'s probably some that I don\'t talk about. They\'re going to be like, "What about this guy? What about this guy?" And that\'s that\'s fair because I could I could make an argument on almost any player as to why something why you would want to just fade off or what if this happens. almost almost any player. Not everyone, but almost anyone. But I\'m not going to do that. So, if there is someone specifically that I don\'t reference here, just drop it in the chat. Drop it in the comments and I\'ll get to it. I I think I\'ll try to, but just that\'s Yeah, I\'m not I can\'t I'),
#  Document(metadata={'source': 'https://www.youtube.com/watch?v=TB2QwCRMams&t=120s', 'start_seconds': 120, 'start_timestamp': '00:02:00'}, page_content="don't think I can get every every person in here as as I want to. Now, you know my definition on this and now usually usually you come to this show and it's just all toxic positivity. I'm telling you how good every player is all the time. Every player is a future superstar in the making. I never talk about when they have bad games or bad situations. I'm always on the optimistic side. So, it's going to be a little bit of a jarring uh day for you today to hear me"),
#  Document(metadata={'source': 'https://www.youtube.com/watch?v=TB2QwCRMams&t=150s', 'start_seconds': 150, 'start_timestamp': '00:02:30'}, page_content="talk about some negatives. But in saying that, to be actually serious for a second, you know my take on injuries. I think if you haven't, welcome to the show. I'm not worried if someone broke their hand and missed 30 games. I don't care that that happened. That doesn't mean they're breaking their hand again. If someone ced a concussion, it doesn't mean they get another one. If someone lost a tooth, they're not getting. It doesn't mean that if someone has multiple injuries to remove parts of the cushioning surface of their knee, then I am worried. I am worried in a big way. And that scares me. If someone strained"),
#  Document(metadata={'source': 'https://www.youtube.com/watch?v=TB2QwCRMams&t=180s', 'start_seconds': 180, 'start_timestamp': '00:03:00'}, page_content="a calf and then hurt their shoulder and then tore their pec, that's really bad luck, man. Like I'm not someone who just uses well this happened last season so that is the be all and end all of everything that goes on. I like to look at everything individually. And some would actually say that for players who are never healthy that I'm way too positive on them or I'm way too optimistic. I just like to go into seasons and talking about players without absolute"),
#  Document(metadata={'source': 'https://www.youtube.com/watch?v=TB2QwCRMams&t=210s', 'start_seconds': 210, 'start_timestamp': '00:03:30'}, page_content='designations. I\'m not going to sit here and say, "Well, LaMelo, he\'ll never play 70 games." Ah, already has. Zion\'s never going to play more than 40 games. Literally one year ago played 70. I I won\'t do that because there\'s every example you can find, there\'s always counters to it. But we\'ll talk about what level of care that you have to have, what level of discount do you have to apply to players when that narrative does exist. So, I hope that sets the'),
#  Document(metadata={'source': 'https://www.youtube.com/watch?v=TB2QwCRMams&t=240s', 'start_seconds': 240, 'start_timestamp': '00:04:00'}, page_content="stage nicely. Again, a lot of you will have watched me for a long time and especially over this preseason as well and you know my takes on some of these players. But as with all of this stuff as well, it's relatively fluid. I could sit here and say I wouldn't take this guy in the top 30 and I'm sitting there at 28 and go I really need those stats. I'll just do it because you shouldn't sit with absolutes with a lot of this stuff. And people often ask me, hey, have you got a list I can just draft off? No. And the reason that I could I could give you a list of names"),
#  Document(metadata={'source': 'https://www.youtube.com/watch?v=TB2QwCRMams&t=270s', 'start_seconds': 270, 'start_timestamp': '00:04:30'}, page_content="and you draft off it. Well done. Right? But it's actually suboptimal that doesn't provide good results. I would never draft off that. So why would I want somebody else to do it that way? It's about having little groupings and and ideas and flexibilities and guys that you can sort, oh, I'll do this this time and maybe I'll do this. But in the end, when you're getting down to nitty-gritty decisions like that, the differences aren't that big. And the same goes with this sort of stuff. I'd never draft this guy, would you? No. Well, what if he sits there at pick 90"),
#  Document(metadata={'source': 'https://www.youtube.com/watch?v=TB2QwCRMams&t=300s', 'start_seconds': 300, 'start_timestamp': '00:05:00'}, page_content="and you said you wouldn't draft him in the first three rounds because who knows? We have to have a level of flexibility, a level of context, a level of individuality, I think, when talking about players. So, let's talk about them. All right. Let's talk about a couple of guys who at first, I'll be honest with you, I didn't actually put them on the list cuz for some reason I just missed them. They do deserve talking about two big men, Anthony Davis and Christos Porzingis. I don't believe you should take Anthony"),
#  Document(metadata={'source': 'https://www.youtube.com/watch?v=TB2QwCRMams&t=330s', 'start_seconds': 330, 'start_timestamp': '00:05:30'}, page_content="Davis in the first round, but that is not necessarily to do with injury history. My projections do not have him sitting. I've seen him go at five, six, seven, eight. I don't like it. I wouldn't take him into the turn. Now, there is a small injury part in that. He looks fat. He busted his eye. He barely played last season. But I'll use the same rational. He played like what 70 games the year before."),
#  Document(metadata={'source': 'https://www.youtube.com/watch?v=TB2QwCRMams&t=360s', 'start_seconds': 360, 'start_timestamp': '00:06:00'}, page_content="So it can happen. But it's more to me that like you are playing at a position that reduces your fantasy stats. You can't really shoot. And at power forward, you're going to have to do more of that. And that should reduce your field goal percentage and it should reduce your blocks and it probably reduces your rebounds to an extent. So I'm down on Davis compared to that. Let's take him in the middle of the first round consensus. So I would take him at the turn 12, 13, 14, 15, that area. That's me. And there's a small"),
#  Document(metadata={'source': 'https://www.youtube.com/watch?v=TB2QwCRMams&t=390s', 'start_seconds': 390, 'start_timestamp': '00:06:30'}, page_content='injury bacon there. What about old mate the infirmary Christo Pzingis who missed like months of last season, could play like five minutes a game in the playoffs due to illness, has had some persistent knee problems. I am higher on Pzingis than most. I know that they are going to be cautious with him. They will keep his minutes a little bit lower in Atlanta. I think I also believe that he will sit on backto-backs, but I also think that on a per game basis, he could easily be a top 20'),
#  Document(metadata={'source': 'https://www.youtube.com/watch?v=TB2QwCRMams&t=420s', 'start_seconds': 420, 'start_timestamp': '00:07:00'}, page_content="player, easily, maybe top 15 and he currently is not dealing with an injury. And last season, he wasn't dealing with an injury. It was a weird out of nowhere illness. I would yeah I said there I would not generally consider him outside the top 35 but there'll be times I'll sit at 31 and go man what Pzingus gives here actually makes sense for me. So again, it's relatively fluid, but you're talking about a top 20 to top 15 player that even like you talk about where"),
#  Document(metadata={'source': 'https://www.youtube.com/watch?v=TB2QwCRMams&t=450s', 'start_seconds': 450, 'start_timestamp': '00:07:30'}, page_content="Pzinga sits at the moment in terms of um where he's going to be drafted like you can get 40s, 50s sometimes to get Pzingers and like the the and so much of this stuff with these injury-prone discount players, it's about like the value becomes too hard to pass up at certain spots. So, I'm just trying to see what puzzling's ADP is. It's 54. Like, it's 63 on fan tracks and 77 on ESPN. They are no-brainer decisions to me. Damonte"),
#  Document(metadata={'source': 'https://www.youtube.com/watch?v=TB2QwCRMams&t=480s', 'start_seconds': 480, 'start_timestamp': '00:08:00'}, page_content="Sabonis is going to miss the beginning of the season in my estimation. He has a hamstring strain. They've just said it's a mild hamstring strain. I know the NBA has no idea how to handle hamstring strains, but a mild hamstring strain should be minimum 10 days. Should probably just be two weeks, which should rule him out for the first week of the season. Now, they are idiots, of course. So, and especially idiots, they are the kings. So, he could play opening night. You all know that I am down on basically every Kings player. I wouldn't draft Sabonis in round one before he hurt his"),
#  Document(metadata={'source': 'https://www.youtube.com/watch?v=TB2QwCRMams&t=510s', 'start_seconds': 510, 'start_timestamp': '00:08:30'}, page_content="hamstring. I probably wouldn't take him in round two in category leagues. Points league is debatable. Now, I'm looking outside the top 30 and honestly might go lower. Maybe it's not that like missing a week of time is a huge deal. It's one week out of let's say 21 weeks before your fantasy playoffs or before your fantasy season ends. Whatever it is, it's not a big deal. It's more that that can linger and we have seen it time and time and"),
#  Document(metadata={'source': 'https://www.youtube.com/watch?v=TB2QwCRMams&t=540s', 'start_seconds': 540, 'start_timestamp': '00:09:00'}, page_content="time and time and time and time and time again that when the NBA brings a player back from a hamstring injury, the rate of recurrence of those injuries is high and then you're looking three weeks out and then it starts to become a problem. So, I was already down on Sabonis. I was already probably not considering him in the top 25 anyway, and now I'll just move him down that little bit extra. We are about to I'm recording this on the 18th of October. We're about to get hit with a flood of injury updates and"),
#  Document(metadata={'source': 'https://www.youtube.com/watch?v=TB2QwCRMams&t=570s', 'start_seconds': 570, 'start_timestamp': '00:09:30'}, page_content="you're not going to be ready for them. This is going to happen like Monday or Tuesday, I think. I don't know this with these ones. Much like the people got like they were shocked that Jiren Jackson played. Why? I I thought that was relatively clear he was going to play and all my decisions were based on that. But like you are going to get an update on the Bronco Jaylen Williams I think that's going to say he is going to be re-evaluated in two to three weeks. I have I think there is no shot that he is playing opening night. I think that"),
#  Document(metadata={'source': 'https://www.youtube.com/watch?v=TB2QwCRMams&t=600s', 'start_seconds': 600, 'start_timestamp': '00:10:00'}, page_content="there is almost no shot he plays in October. I think he might be out like maybe Thanksgiving. I don't know. These are gut instincts. Nobody has told me this. I've seen Jaylen Williams in at times go at pick 11 or 12. I think people are starting to get a little bit more worried now. But he to me is not a first three round guy for the injury reason, but also for some of the performance stuff that I think the defensive stats was fueled a little bit a lot by the early season numbers last season playing"),
#  Document(metadata={'source': 'https://www.youtube.com/watch?v=TB2QwCRMams&t=630s', 'start_seconds': 630, 'start_timestamp': '00:10:30'}, page_content="at center. So, but this injury is not great to me. Not a top 35 player. LaMelo not injured. Except today's preseason game, they're listing him out with a knee contusion. I'm not worried about that, but we'll see. He's currently not injured. LaMelo very much can be a top 10 per game player. I would not take him outside the top 20, but when you get to like pick 23, 24, and you're looking on the board, you go, what am I going to do here? Cuz"),
#  Document(metadata={'source': 'https://www.youtube.com/watch?v=TB2QwCRMams&t=660s', 'start_seconds': 660, 'start_timestamp': '00:11:00'}, page_content='LaMelo makes a lot of sense. He has had a lot of ankle injuries. But I will also continue to say this. The reason that he sat out down the stretch last season was not really an injury. He sat out because the team was winning had won 10 games and they were trying to maximize lottery odds. And yeah, he has ankle soreness. He has wrist soreness. He played some backto-backs last season. He barely got hurt in the first three months and then Brandon Miller went down and it all turned to crap. The problem I have with LaMelo this season is the team is crap. So are we going to get the same thing crop up'),
#  Document(metadata={'source': 'https://www.youtube.com/watch?v=TB2QwCRMams&t=690s', 'start_seconds': 690, 'start_timestamp': '00:11:30'}, page_content="again? because otherwise I don't think I'd really be worried. I wouldn't do it inside the top 20 for LaMelo. LeBron had a knee injury in the playoffs, came back, barely has done any basketball work, it seems, since July, has a sciatic nerve injury. Won't be available till mid November. They're going to be really cautious. Yeah, you should be incredibly cautious about this. I already didn't have LeBron in my top 25 because he is old. Now there's all this other drama"),
#  Document(metadata={'source': 'https://www.youtube.com/watch?v=TB2QwCRMams&t=720s', 'start_seconds': 720, 'start_timestamp': '00:12:00'}, page_content="with the Lakers and this injury. No way that I'm touching LeBron in the top 50. There's no way that I'm doing it. I'm just there's I'm not because not only that if he comes back say mid November, you've missed a month already. He's going to be cautious. He's going to sit games. This is a type of injury that can easily flare up and get worse at any point. Plus, guess what? He is old. Something else can happen. I would not touch him in the top 50. I was also lower on Darren Fox than most people and now he"),
#  Document(metadata={'source': 'https://www.youtube.com/watch?v=TB2QwCRMams&t=750s', 'start_seconds': 750, 'start_timestamp': '00:12:30'}, page_content="has a hamstring injury that's probably going to miss the start of the season. So I said I wouldn't touch Darren Fox inside the top 50. Now largely for me that's that was based on projections. He was not good in San Antonio. There are other players with the ball. Castle, Dylan Harper, and of course the big man Victor Emanyama. I was not like Fox at 20 or 30 before the injury at all. Not even close to it. So, this injury pushes him outside the top 50 to me and I'm pretty comfortable with that. We'll come back talk about"),
#  Document(metadata={'source': 'https://www.youtube.com/watch?v=TB2QwCRMams&t=780s', 'start_seconds': 780, 'start_timestamp': '00:13:00'}, page_content="some more injuryprone or injured players or what we're doing in the drafts with them. Today's episode though, it is brought to you by Wayfair. The holidays, they're going to be here before you know it. Maybe the holidays are here before LeBron is back, but that's exciting. Um, you got to get your homes ready though. People to come over, events to host, but you've got everything in order. Have you got your beds sorted, your linens, your beddings, your silverware, serving wear, table wear, whatever wear. Have you got it all? Cuz Wayfair can do it at any style and any budget. Wayfair has all the things that you need to personalize"),
#  Document(metadata={'source': 'https://www.youtube.com/watch?v=TB2QwCRMams&t=810s', 'start_seconds': 810, 'start_timestamp': '00:13:30'}, page_content="your home for the holidays. You might want outdoor furniture setting. You might live in a place where it's getting a little bit cooler. Maybe they got one of those like outsour outside uh fires, bonfire type things. What's the thing called? Chimara. Chima. I don't know. Something you can get at Wayfair, I'm sure. Get organized, refreshed, and ready for the holidays for way less. Head to wayfair.com right now to shop all things home. That's wf a r.com. Wayfair every style, every home."),
#  Document(metadata={'source': 'https://www.youtube.com/watch?v=TB2QwCRMams&t=840s', 'start_seconds': 840, 'start_timestamp': '00:14:00'}, page_content="We are talking dudes who get hurt. It's not probably the real name of the show, but that's what we're talking about. Guys who are currently hurt. What do we do with them? When do we pick them? Um, do we pick them? You might be someone who's like, I am never touching this player. Do not draft. If you want that information from this show, you're not getting it. Thanks for tuning in this far. I'll see you next time. Zion Williamson. I believe I believe Zion Williamson is a"),
#  Document(metadata={'source': 'https://www.youtube.com/watch?v=TB2QwCRMams&t=870s', 'start_seconds': 870, 'start_timestamp': '00:14:30'}, page_content="very clear top 10 points league player and a pretty clear top 20 head-to-head category player. Roto probably outside the top 40. Different story. Zion is healthy. Zion played 70 games two years ago. Now to be fair, he had played zero games in one season. He has barely played. And last season, he played like 30 games with a hamstring injury. They also kept his minutes down. And the the worry I have with Z is the recurrent hamstring. That's not as worrying to me as a recurrent knee"),
#  Document(metadata={'source': 'https://www.youtube.com/watch?v=TB2QwCRMams&t=900s', 'start_seconds': 900, 'start_timestamp': '00:15:00'}, page_content="cartilage, meniscus injury. But it's probably the worst recurrent soft tissue injury you can have in terms of if someone continues to ping their hamstring, it's right up there with pinging your calf multiple times. It's not great. I would be I would take Zion in round one or round two if there was none of that history. Not not even a no question from me, but that does exist and I am worried and also that team is trash. They are terrible. I'm that team is going to be so bad. They are I don't know which team I'm going to rant about their front office more"),
#  Document(metadata={'source': 'https://www.youtube.com/watch?v=TB2QwCRMams&t=930s', 'start_seconds': 930, 'start_timestamp': '00:15:30'}, page_content='whether it\'s the Pelicans or the Kings this season. I would not take Zion in most cases inside the top 30. There will be times that I might sit at 27 and go, "Yeah, Zion looks pretty good here." Look, I did it yesterday in that live draft that I did where I I didn\'t do it, but I was I took Giannis at five and we got back to round three. I go, "Do I do Zion here? I\'m pretty interested in taking Zion." I didn\'t, but I was interested in it. But as a general thing, top 30 I think is fine.'),
#  Document(metadata={'source': 'https://www.youtube.com/watch?v=TB2QwCRMams&t=960s', 'start_seconds': 960, 'start_timestamp': '00:16:00'}, page_content='Demetrius Morant, when John Morant hurt his ankle, um Memphis beat reporters were like, I this is this is nothing. We think this is just preservation and he\'s all good. He was asked about it and they was like, "J, what do you think about people that think that you will not be there opening night and he said something along the lines they be tweaking?" Which I guess means they\'re full of crap, right? And then, but of course, the Grizzlies put out an injury report and remember, you cannot you cannot trust the Grizzlies injury report at all. They said he\'s weak to just'),
#  Document(metadata={'source': 'https://www.youtube.com/watch?v=TB2QwCRMams&t=990s', 'start_seconds': 990, 'start_timestamp': '00:16:30'}, page_content='remember this team is either the most dishonest injury reporting team in the league or the dumbest injury reporting team in the league. And I don\'t know which one it is. The amount of times I\'ve said, "Oh, he\'s got a grade three sprain." Uh, two days. It\'s not It\'s not really how grade threes work, my guy. So, when they say week to week, do they actually know what it means or are they deliberately lying? I still, and I believe this with Jarren Jackson, and he\'s buying, I still believe that Morant'),
#  Document(metadata={'source': 'https://www.youtube.com/watch?v=TB2QwCRMams&t=1020s', 'start_seconds': 1020, 'start_timestamp': '00:17:00'}, page_content="will be available opening night. And if he's not, it might be a day or two. So, I'm not that worried about it. But the problem of course is is how many knee and back and shoulder and whatever sort of issues Morant has had through his play style. These are not they're unlucky so to speak, but it is his play style that causes this. I think Morant is a top 20 points league guy. I think that he is underrated for category leagues. Maybe top 25. I wouldn't take him inside the top 40. I think we got this idea. I"),
#  Document(metadata={'source': 'https://www.youtube.com/watch?v=TB2QwCRMams&t=1050s', 'start_seconds': 1050, 'start_timestamp': '00:17:30'}, page_content='said this to Dan Bus when I was on his show a few weeks ago that we still have this idea. People go, "He\'s terrible for nine cat. He never gets steals. He never hits threes. He can\'t hit free throws." And that\'s all not true. By the way, just got to look at his numbers. Like those things have changed. So yeah, top 40. Kawhai. Kawhai is healthy. Kawhai is awesome. Kawhai is a first round player. I wouldn\'t take him inside the top 45 for a very specific reason. And you know what the reason is? I I\'ll just put him and Joel Embiid together. It looks like both guys will play opening night.'),
#  Document(metadata={'source': 'https://www.youtube.com/watch?v=TB2QwCRMams&t=1080s', 'start_seconds': 1080, 'start_timestamp': '00:18:00'}, page_content="Embiid more debatable. They have had multiple knee surgeries on the same knee to remove parts of their meniscus which provides the cushioning which helps reduce the swelling that happens when you jump up and down on a hard surface. We have seen this time and time and time and time and time and time and time again. It is absolutely possible that Kawhai plays 65 games, Embiid plays 60 games. They're both first round players and you"),
#  Document(metadata={'source': 'https://www.youtube.com/watch?v=TB2QwCRMams&t=1110s', 'start_seconds': 1110, 'start_timestamp': '00:18:30'}, page_content='get steals when you pick them in the 50 in the 40s. That is I I acknowledge that that is actually quite possible. I am very happy to just miss out on that cuz to me when you have and not actually not to me because the medical research backs this up. When you have meniscus repairs, miniscia repairs, multiple of them,'),
#  Document(metadata={'source': 'https://www.youtube.com/watch?v=TB2QwCRMams&t=1140s', 'start_seconds': 1140, 'start_timestamp': '00:19:00'}, page_content="or more importantly, meniscus removals, the chances of you having a reinjury is like 80% on that miniscus. The studies are that number, don't quote me on it. It is an incredibly high number of those of those injuries recurring very soon after. Embedded had another knee procedure, I believe, in the offseason. Kawhai was healthy last season, but remember he did not start until January. So, is he going to play until January this time and then be out for two months? Maybe he they they could both play all the way"),
#  Document(metadata={'source': 'https://www.youtube.com/watch?v=TB2QwCRMams&t=1170s', 'start_seconds': 1170, 'start_timestamp': '00:19:30'}, page_content="through, but I'm not taking Kawhai in the top 45. I'm not taking him be in the top 50. And I will wear it. I will be happy or happy for them, happy for you if they play through. Now, in a Roto League, I actually took both guys. I took Kawawaii in the 40s and inbid in the 50s in a roto league because in a roto it is easier to deal with and I don't have to worry about the fact that hey if Kawaii plays the bigger the season he's up there they're in the playoffs I don't have to worry about that but that's the only circumstance. Larry Markin is he actually injured or"),
#  Document(metadata={'source': 'https://www.youtube.com/watch?v=TB2QwCRMams&t=1200s', 'start_seconds': 1200, 'start_timestamp': '00:20:00'}, page_content='not? I don\'t know. I honestly don\'t know. I don\'t know if he\'s going to be injured. I don\'t know how injured he was last season. I know he\'s had some hand and wrist issues. We all have. But to me, this team, and I want I I saw this quote resurface again today that Austin Angel is like, "We\'re not going to be tanking." He did not say that. What he said is, "We\'re not going to be in-game manipulating minutes," which is a very easy way to get people to think that you say you\'re not tanking, but'),
#  Document(metadata={'source': 'https://www.youtube.com/watch?v=TB2QwCRMams&t=1230s', 'start_seconds': 1230, 'start_timestamp': '00:20:30'}, page_content="you're tanking. They are tanking. I give you with 99% assurance they are tanking. Markin, not only did he just miss a bunch of time, he was bad when he played last season and he's going in like the 50s. I would not touch Larry Markin in the top 80s. In the top 80, I wouldn't do it. A, I don't know how good he's going to be. B, I don't know that he I'm pretty sure he's not going to be there, at least reliably, in the fantasy playoffs. I'm I'm not doing it. I am not doing it."),
#  Document(metadata={'source': 'https://www.youtube.com/watch?v=TB2QwCRMams&t=1260s', 'start_seconds': 1260, 'start_timestamp': '00:21:00'}, page_content="Daryus Garland is dealing with a toe injury and I think that he can be a top 45 per game player. The problem is here is I don't know how long he's going to be out. I don't think it's going to be long. maybe two weeks. But we have seen this that unless Darius Garland is absolutely brand spanking new, looking great, feeling good, he struggles, broken jaw, ruined an entire season. Last season hurt his hip, he was flying"),
#  Document(metadata={'source': 'https://www.youtube.com/watch?v=TB2QwCRMams&t=1290s', 'start_seconds': 1290, 'start_timestamp': '00:21:30'}, page_content="like top 25. Came back, played, not the same guy. So I do worry that his rampups take longer. So, I wouldn't draft Darius Garland inside the top 60 because I do think that when you get to the fantasy playoffs, he might be rolling top 40, but the worry is that it takes him until February to get get to that just because of how long his ramp up does take. Tyler Herro, we got this weird report from Dominique Wilkins about him talking to Heat training staff saying he'd be"),
#  Document(metadata={'source': 'https://www.youtube.com/watch?v=TB2QwCRMams&t=1320s', 'start_seconds': 1320, 'start_timestamp': '00:22:00'}, page_content="ready for the opener and that just nothing else. Nothing else followed. I don't think we're going to get an update on that saying that Hero is available and I'm still expecting at least four more weeks for Tyler. I think that he could have been a top 30 player this season, but ankle surgery means that when he does come back, if there's no setbacks, he still has to ramp up. He still has to regain confidence. He still has to regain conditioning. He still will sit back to backs. So, you might not literally get full steam Tyler Hero until Christmas."),
#  Document(metadata={'source': 'https://www.youtube.com/watch?v=TB2QwCRMams&t=1350s', 'start_seconds': 1350, 'start_timestamp': '00:22:30'}, page_content="I would be okay with him outside the top 70. But all of these decisions, guys, it depends what else I've done. Did I take LaMelo? Did I take Zion? So, I'm not stacking LaMelo, Zion, Garland, Markin, and Hero. That's idiotic in head-to-head leagues. Walking Kesler have got outside the top 80. Now, yesterday he started, he hit a three, he got eight assists. People are very excited about it. Cool. He hadn't played all preseason. He played that first game. It obviously means that Ysef Nerkage is not going to have that"),
#  Document(metadata={'source': 'https://www.youtube.com/watch?v=TB2QwCRMams&t=1380s', 'start_seconds': 1380, 'start_timestamp': '00:23:00'}, page_content="opening night value. That's cool. But this is just what I said with Markin. I think that they're going to be bad. I think he's going to miss games. Not as many as Mark and down the stretch. He's very limited overall in his fantasy production. And I am worried about it. I got Brandon Ingram outside the top 60. Why? Because I think he might be a top 40 per game guy. Now he is also not currently injured. He also played 18 games last season. And I I will not on this show"),
#  Document(metadata={'source': 'https://www.youtube.com/watch?v=TB2QwCRMams&t=1410s', 'start_seconds': 1410, 'start_timestamp': '00:23:30'}, page_content='will not go into discussions and talking about players and their alleged mindsets. I I don\'t do that. You You will hear so many people talk this guy soft. He doesn\'t want it. He won\'t play. He never cares. I I will not do that except in this instance because this is not me speculating. This has been reported that his teammates have gone, "Bro, you can play. why aren\'t you out there? Like that has happened.'),
#  Document(metadata={'source': 'https://www.youtube.com/watch?v=TB2QwCRMams&t=1440s', 'start_seconds': 1440, 'start_timestamp': '00:24:00'}, page_content="Frustrations emerge from the Pelican's locker room suggesting that maybe Brennan Ingram is uh healthy and just choosing not to get out there. That those reports have surfaced. Now, if he doesn't get hurt, then whatever. There's literally no problem. But that gives you a hey, this guy always seems to take longer to recover. We got a little bit of documented evidence of this. He he has been very good. He is killing Scotty Barnes, but he looks very good,"),
#  Document(metadata={'source': 'https://www.youtube.com/watch?v=TB2QwCRMams&t=1470s', 'start_seconds': 1470, 'start_timestamp': '00:24:30'}, page_content="but I probably wouldn't do it until outside the top 60. And then Michael Porter Jr., not only has he had a history of back injuries and then a shoulder in the playoffs, but the Nets are going to be terrible. He is going to be very bad to watch. And I just don't think that he will play very much in the fantasy playoffs. So, I would not touch him outside the inside the top 80. He could easily be top 50 per game. Easily. He could average 25 a game. Maybe, probably not, cuz Cam Thomas going to take 80 shots. But Porter could average a lot. But I just don't think he's going"),
#  Document(metadata={'source': 'https://www.youtube.com/watch?v=TB2QwCRMams&t=1500s', 'start_seconds': 1500, 'start_timestamp': '00:25:00'}, page_content="to be available. And before you say availability is the best ability, go take Harrison Barnes in the first round. Put your money where your mouth is. Barnes round one cuz he played 82 games. Chris Paul round two. We'll put Muel Bridges in round one as well. Bang. Best. No, the best ability is ability. I'll fight you on it. That's the best ability. But anyway, um I'd never know what I was saying. Yeah,"),
#  Document(metadata={'source': 'https://www.youtube.com/watch?v=TB2QwCRMams&t=1530s', 'start_seconds': 1530, 'start_timestamp': '00:25:30'}, page_content="Michael Porter could be good, but if he's not there for the playoffs, what is the purpose? We'll come back with more. Today's episode, it is brought to you by Fanel. The NFL season is here. Fanel has an offer you won't want to miss. Right now, new customers can bet just $5 and get $300 in bonus bets. If you win, you pick a bet, you put five bucks down, and if it hits, you will unlock $300 in bonus bets to use across the app. When you're watching sport, you know what you're talking about. I'm sure you're watching, this is something interesting. I like the way this guy's playing. Maybe we"),
#  Document(metadata={'source': 'https://www.youtube.com/watch?v=TB2QwCRMams&t=1560s', 'start_seconds': 1560, 'start_timestamp': '00:26:00'}, page_content="look at his live uh player props. Maybe we check the spread. Maybe we do a a same game parlay for the next upcoming game. Or we look at futures across the NBA. So, what are you waiting for? Go to fanul.com, download the FanDuel app today, and get started. And don't forget to gamble responsibly. We're talking about when and where to draft injured players or guys that we're worried about heading into the season. You might have different answers for these guys and that is totally okay. I'm just giving you some of my thoughts as to where we draft these guys. Now,"),
#  Document(metadata={'source': 'https://www.youtube.com/watch?v=TB2QwCRMams&t=1590s', 'start_seconds': 1590, 'start_timestamp': '00:26:30'}, page_content="Jaylen Green, hurt his hamstring, came back to practice, and guess what he did? Oh no. Hurt his hamstring again. Um I Jaylen Green. This is a this is categories for points leagues top 50 player per game. Category leagues I think probably top 80 per game. But the iron man that he is also remember this if you have not been injured in the past that that doesn't mean a single"),
#  Document(metadata={'source': 'https://www.youtube.com/watch?v=TB2QwCRMams&t=1620s', 'start_seconds': 1620, 'start_timestamp': '00:27:00'}, page_content="thing. It means nothing. And I I will continue to show you evidence of this de Mont ke and mar Jen Green all these players who are not going to be available for the start of the season who just never miss time and their durability they always want to be there right doesn't matter so I'd put green for category leagues outside the top 120 for points leagues outside the top 75 cuz he's going to miss time I think he probably misses three to four weeks honestly but I also noticed and I say"),
#  Document(metadata={'source': 'https://www.youtube.com/watch?v=TB2QwCRMams&t=1650s', 'start_seconds': 1650, 'start_timestamp': '00:27:30'}, page_content="this I also noticed that I've mixed top. So, I mixed up Jaylen Green and Jaylen Suggs is top number. Jayen Green is out to the top 80. Suggs is top 120. So, my bad on that. Jaylen Green is top 80. So, ignore that. Top 120. 180. Uh, top 80 for Jaylen Green. Paul George, don't think he's going to be available opening night. I would guess maybe a week or so into the season, but that's another knee surgery for George. I was"),
#  Document(metadata={'source': 'https://www.youtube.com/watch?v=TB2QwCRMams&t=1680s', 'start_seconds': 1680, 'start_timestamp': '00:28:00'}, page_content="relatively okay with a bounceback for Paul this season. Not really now. I wouldn't touch him inside the top 80. His per game numbers were bad last season. His shooting was terrible. His steel numbers were still pretty good and he had some okay assist numbers. His usage tailed off, but a knee injury to begin the season is not great. So to me, top 80. Same with Michael Porter. But Cam Thomas, I'm not touching in the top 80. In fact, I might even push him to 100. But honestly, I get that if you want the scoring or if you're in a points league, you go a little bit higher on Thomas, but it's the same"),
#  Document(metadata={'source': 'https://www.youtube.com/watch?v=TB2QwCRMams&t=1710s', 'start_seconds': 1710, 'start_timestamp': '00:28:30'}, page_content="story. He's going to be bad. They have no future investment in him and he's just not going to play down the stretch is my guess. The big fella, Mark Williams, is looking like he'll be available opening night and I think for the first week or so, we might see him at 25 minutes, but I do think that he will push to 29 to 30. I think he'll very clearly be the Sun's best center. 31 minute Mark Williams is a top 25 player, so be aware of that. But we do have to have concerns about him clearly. I wouldn't draft him inside the top 60. I would consider it, but I wouldn't draft him there. And then this is the"),
#  Document(metadata={'source': 'https://www.youtube.com/watch?v=TB2QwCRMams&t=1740s', 'start_seconds': 1740, 'start_timestamp': '00:29:00'}, page_content="one that was meant to be outside the top 120, and that's Jayen Suggs. I know what you'll tell me that Jayen Suggs was great and he was a top 80 player last season, but there is so much reason to have doubts about that. He had 28% usage and did it all with no Desmond Bane, no Franvagen, no Palao, and that's not how the season goes. Plus, again, he is not ready for opening night. He looks weeks away. Honestly, maybe not, but like he's I think he just started taking contact yesterday. He's weeks away."),
#  Document(metadata={'source': 'https://www.youtube.com/watch?v=TB2QwCRMams&t=1770s', 'start_seconds': 1770, 'start_timestamp': '00:29:30'}, page_content="He's had a history of injuries. They have Mr. Black and Tus Jones. There is no way to me that Suggs is anything more than a last round flyer. I I cannot get behind anything more than that. Bradley Beiel hasn't played in the preseason. I thought there was a chance for Bill to have an okay season, but now he's got a knee problem. I said outside the top 100 I might actually go top 120 now. Like I'm just continued to think about and look I'm just a little concerned. Jaden Ivy broke his leg last season. Shot really well."),
#  Document(metadata={'source': 'https://www.youtube.com/watch?v=TB2QwCRMams&t=1800s', 'start_seconds': 1800, 'start_timestamp': '00:30:00'}, page_content="Still has a lot of empty holes in his game and then you know I was a little worried about how does he fit with Cade in terms of replacing the shooting of Hardway and Beasley and that sort of stuff. And now he has a knee procedure because there was knee swelling and it's going to be minimum four weeks but that's a minimum. And then is that an ongoing problem? I don't think he's draftable honestly in most 12 team leagues. If you want to take him in your last round, go for it. But this is four weeks for a guy that's not that good to begin with with a situation that could persist. Keegan Murray I thought was getting underdrafted. I thought he could get him"),
#  Document(metadata={'source': 'https://www.youtube.com/watch?v=TB2QwCRMams&t=1830s', 'start_seconds': 1830, 'start_timestamp': '00:30:30'}, page_content="around to pick a 100. He was probably the only Kings guy that I liked. He doesn't really have any room to ramp up his usage, which is frustrating. But now he has this thumb injury which is going to cost him four to six weeks. There was a report that said that might be three months. don't really know that that's true, but it was reported. And given that your upside is so bloody low and they then brought in Russell Westbrook, how do we do Keegan inside the top 130? I don't see how you do it. I think Zack Edy, healthy Zach Edit, top 50 player this season, but he's not."),
#  Document(metadata={'source': 'https://www.youtube.com/watch?v=TB2QwCRMams&t=1860s', 'start_seconds': 1860, 'start_timestamp': '00:31:00'}, page_content="He's going to miss time. Is he back at Thanksgiving? And then as a 7 foot 4, 300 lb man, numbers are rough. How is he going to go recovering from ankle surgery? He's going to sit back to backs. He's going to have limited minutes, which is frustrating. Now, I think that when you get to the fantasy playoffs, he might be rolling top 60. So, I wouldn't take him inside the top 100. And it would all depend on what I've done in the other rounds. Do I have the injured slots? Did I take Jaylen"),
#  Document(metadata={'source': 'https://www.youtube.com/watch?v=TB2QwCRMams&t=1890s', 'start_seconds': 1890, 'start_timestamp': '00:31:30'}, page_content="Williams? Did I take Zion? And then did I take Darius Garland? And now Ed is my third injured slot and I have nothing available. Can I survive with no flexibility for a week or two? Maybe, but not much more than that. But there's huge upside in Edia, especially that area of the draft where you're looking out to the top 100. The centers there are pretty rough. But it could be January until full 80 is there. People were drafting TJ McConnell a lot getting those 21 22 minutes assists and steals, high field goals. It's a good combination."),
#  Document(metadata={'source': 'https://www.youtube.com/watch?v=TB2QwCRMams&t=1920s', 'start_seconds': 1920, 'start_timestamp': '00:32:00'}, page_content="He was still going to be the backup behind Andrew Neard, but now he's hurt his hamstring and it doesn't appear like it's a mild one. I would say a month here at least. I don't think that I would bother with McConnell in a standard league. Now, as always, if you've got open slots in IIL, fill him, put TJ in there, draft him, and put him there. But remember is that if you just keep holding and blocking those IIL slots, you will get to a stage when you have a guy on your bench that's injured. And that means three to four"),
#  Document(metadata={'source': 'https://www.youtube.com/watch?v=TB2QwCRMams&t=1950s', 'start_seconds': 1950, 'start_timestamp': '00:32:30'}, page_content="games fewer per week, maybe as much as five or six because you you're limited in your streaming now. So just be cautious about that. The upside of McConnell is not good enough to sacrifice that. Let's talk about some of the big ones here. Jason Tatum, don't bother. I know he said that he might come back. Do you know how often this has worked? Never. I'm not saying that like he heard his Achilles in May. We are seeing players from Achilles come back in 10 months or"),
#  Document(metadata={'source': 'https://www.youtube.com/watch?v=TB2QwCRMams&t=1980s', 'start_seconds': 1980, 'start_timestamp': '00:33:00'}, page_content="so. They're not the same when they come back. But let's be realistic. If he does come back and play this season, Jason Tatum, when will it be? March. When does your fantasy season even end? And then when he comes back, is he playing 35 minutes? Is he going to be the same? Is he going to play back to back? The answer to all those is no. So what are you holding on to a Jason Tatum in your injured slot and burning it for for four four five months for"),
#  Document(metadata={'source': 'https://www.youtube.com/watch?v=TB2QwCRMams&t=2010s', 'start_seconds': 2010, 'start_timestamp': '00:33:30'}, page_content='no point to me. Desantto Murray tories Achilles on January the 31st. He has expressed displeasure with the Pelicans and the organization and all that sort of stuff. I think that he\'ll be back maybe in January. I think he\'ll push closer to 12 months on this injury honestly. But also they have Jeremiah fears hers Alvarado Jordan P. They\'re not going to be going anywhere. There\'s a long-term injury recovery that I just would not bother drafting him. Kyrie Irving to his ACL in March. I know there\'s going to be someone here go, "Well, actually in European soccer in'),
#  Document(metadata={'source': 'https://www.youtube.com/watch?v=TB2QwCRMams&t=2040s', 'start_seconds': 2040, 'start_timestamp': '00:34:00'}, page_content='six months, you can be back from an ACL." Cool. Doesn\'t happen in basketball. Different game, different movements, different surface that you\'re playing on, which is important. Kyrie might come back and be available in February, but when he does, he will also miss back to backs. He will also have a ramp up period and he\'ll also have some struggles as players come back from their ACL usually shoot quite poorly. And I do not want to hold my injured slot hostage for four or five'),
#  Document(metadata={'source': 'https://www.youtube.com/watch?v=TB2QwCRMams&t=2070s', 'start_seconds': 2070, 'start_timestamp': '00:34:30'}, page_content="months. It doesn't make sense. To finish this off, two young guards, Sterling Henderson, Scoot, bad hamstring strain. They said up to 10 weeks. So, we're think three or four weeks into that. But that means that again, Thanksgiving and when he comes back, what's he going to do? We already knew they had seven starters for five spots and he's already got he's well behind the eightball. You have to come in on limited minutes and play off the bench"),
#  Document(metadata={'source': 'https://www.youtube.com/watch?v=TB2QwCRMams&t=2100s', 'start_seconds': 2100, 'start_timestamp': '00:35:00'}, page_content="and play 25 minutes and waste your IIL slot for 6 weeks. I wouldn't do it unless it's my only guy that I'm drafting that's injured and I would have no hesitation in cutting him. I put this one in here. We don't have an update on it yet, but Bob Carrington hurt his knee yesterday. Didn't look great. Reminder, played 82 games last season. hurt his knee, didn't put any pressure on it. He also looked terrible in the preseason. And for a guy that you'd be just be taking a late flyer on who did not look good, and now hurt his knee. Again, I don't have an update in this. I just wouldn't bother drafting"),
#  Document(metadata={'source': 'https://www.youtube.com/watch?v=TB2QwCRMams&t=2130s', 'start_seconds': 2130, 'start_timestamp': '00:35:30'}, page_content="him in a 10 or 12 league, I would not bother. He might start, but what am I actually missing out on? I don't think I'd bother. I also didn't include this one on here, but Jaylen Brown left the game with hamstring tightness. I this happens quite a bit after knee surgery that you get sort of what's it called like referred injuries through other parts of your leg and that's exactly what Brown has. The Celtics team I'm certain is going to be bad and I'm certain they're going to be very cautious with Jaylen Brown. So while you"),
#  Document(metadata={'source': 'https://www.youtube.com/watch?v=TB2QwCRMams&t=2160s', 'start_seconds': 2160, 'start_timestamp': '00:36:00'}, page_content="think that he's going to get this big usage bump might has a lot of other deficiencies plus I just don't think he's going to play that much. So for Jaylen, given this latest hamstring thing, we'll see how much time he misses, if any. I'm not I wouldn't do it in the top 40 and it might not be top 50 for Jaylen Brown. Might not. But that's I don't that and the Bub one. We don't really have any sort of concrete uh updates on it. And"),
#  Document(metadata={'source': 'https://www.youtube.com/watch?v=TB2QwCRMams&t=2190s', 'start_seconds': 2190, 'start_timestamp': '00:36:30'}, page_content="that is a look at some players that are injured or injury prone. Tell me if there's somebody that I missed that you wanted to hear about and we can chat about it in the comments. Hit the hype if you're on the YouTube mobile app. Thumb it up and subscribe and leave comments, double bang, audio, video, all that stuff. Guys, we are done here. Thank you so much for listening"),
#  Document(metadata={'source': 'https://www.youtube.com/watch?v=TB2QwCRMams&t=2220s', 'start_seconds': 2220, 'start_timestamp': '00:37:00'}, page_content='everyone. See you. [Music]')]
